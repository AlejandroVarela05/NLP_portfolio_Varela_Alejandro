# %% [markdown]
# # S06 - Evaluation Metrics
# ## Exercises

# %% [markdown]
# ### Exercise 1 (Easy)
# Calculate accuracy, precision, recall, and F1 manually from a confusion matrix.

# %%
# Confusion Matrix:
# Predicted:  Pos  Neg
# Actual Pos: 40   10  (TP=40, FN=10)
# Actual Neg:  5   45  (FP=5, TN=45)

TP, FP, FN, TN = 40, 5, 10, 45

# Calculate metrics
accuracy = (TP + TN) / (TP + FP + FN + TN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1 = 2 * (precision * recall) / (precision + recall)
# Print results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.85
# Precision: 0.89
# Recall: 0.80
# F1 Score: 0.84

# %% [markdown]
# ### Exercise 2 (Easy)
# Use sklearn to compute these metrics for a classification result.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

y_true = [1, 1, 1, 0, 0, 0, 1, 0, 1, 0]
y_pred = [1, 0, 1, 0, 1, 0, 1, 0, 0, 0]

# Calculate all metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
cm = confusion_matrix(y_true, y_pred)
# Print results
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")        
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print("Confusion Matrix:")
print(cm)
# Out:
# Accuracy: 0.70
# Precision: 0.75
# Recall: 0.60
# F1 Score: 0.67
# Confusion Matrix:
# [[4 1]
#  [2 3]]

# %% [markdown]
# ### Exercise 3 (Medium)
# Generate and visualize a classification report for a multi-class problem.

# %%
from sklearn.metrics import classification_report
import numpy as np

# 3-class problem: 0=negative, 1=neutral, 2=positive
y_true = [0, 0, 1, 1, 2, 2, 0, 1, 2, 0, 1, 2]
y_pred = [0, 1, 1, 1, 2, 1, 0, 0, 2, 0, 1, 2]

# Generate classification report
report = classification_report(y_true, y_pred, target_names=['Negative', 'Neutral', 'Positive'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.75      0.75      0.75         4
#      Neutral       0.60      0.75      0.67         4
#     Positive       1.00      0.75      0.86         4
#
#     accuracy                           0.75        12
#    macro avg       0.78      0.75      0.76        12
# weighted avg       0.78      0.75      0.76        12

# %% [markdown]
# ### Exercise 4 (Medium)
# Plot a ROC curve and calculate AUC for a binary classifier.

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predicted probabilities (not class labels)
y_true = [0, 0, 1, 1, 0, 1, 0, 1, 1, 0]
y_scores = [0.1, 0.4, 0.35, 0.8, 0.2, 0.9, 0.3, 0.6, 0.7, 0.25]

# Plot ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Exercise 5 (Hard)
# Implement macro and micro averaging for precision/recall in a multi-class problem.
#
# *Research: Macro = average per class, Micro = global counts*

# %%
def macro_precision(y_true, y_pred, num_classes):
    # Your implementation
    total_precision = 0
    for c in range(num_classes):
        TP = sum((y_true[i] == c and y_pred[i] == c) for i in range(len(y_true)))
        FP = sum((y_true[i] != c and y_pred[i] == c) for i in range(len(y_true)))
        precision_c = TP / (TP + FP)
        total_precision += precision_c
    return total_precision / num_classes
    pass
def micro_precision(y_true, y_pred, num_classes):
    # Your implementation 
    TP = sum((y_true[i] == y_pred[i]) for i in range(len(y_true)))
    FP = sum((y_true[i] != y_pred[i]) for i in range(len(y_true)))
    return TP / (TP + FP)   
    pass


print("Macro Precision:", macro_precision(y_true, y_pred, num_classes=3))
print("Micro Precision:", micro_precision(y_true, y_pred, num_classes=3))
# Out:
# Macro Precision: 0.5
# Micro Precision: 0.6
